# %% [markdown]
# # Markdown

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# ## Header 2

# %%
# Parameters
g = 9.81
m = 5
q = 4

# %%
# Weight
W = m * g
print(W)
# Out:
# 49.050000000000004

# %% [markdown]
# # Section

# %% [markdown]
# This is the formula for chain rule
#
# $$
# \frac{dy}{dx}=\frac{dy}{dz}\times\frac{dz}{dx}
# $$
#
# This is my list
# - object 1
# - object 2
# - object 3

# %% [markdown]
# ![image1](Tux.png)

# %% [markdown]
# # Keyboard Shortcuts

# %%
def addition():
    return None

def process_data():
    item_1 = division(data_1)
    item_2 = division(data_2)
    item_3 = division(data_3)
    item_4 = division(data_4)
    item_5 = division(data_5)
    
    return [item_1, item_2, item_3, item_4, item_5]
